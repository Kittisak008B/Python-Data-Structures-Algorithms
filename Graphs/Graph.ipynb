# %%
{
    'A':['B', 'C'],
    'B':['A', 'C'],
    'C':['B', 'A']
}
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'C'], 'C': ['B', 'A']}

# %%
class Graph :
    def __init__(self) :
        self.adj_list = {}

    def print_graph(self) :
        for vertex in self.adj_list :
            print(vertex, ':',self.adj_list[vertex])

    def add_vertex(self, vertex) :
        if vertex not in self.adj_list.keys() :
            self.adj_list[vertex] = []
            return True
        return False

    def add_edge(self, v1, v2) :
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True
        return False

    def remove_edge(self, v1, v2) :
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            try :
                self.adj_list[v1].remove(v2)
                self.adj_list[v2].remove(v1)
            except ValueError :
                pass
            return True
        return False

    def remove_vertex(self, vertex) :
        if vertex in self.adj_list.keys() :
            for other_vertex in self.adj_list[vertex] :
                self.adj_list[other_vertex].remove(vertex)
            del self.adj_list[vertex]
            return True
        return False

# %%
a = Graph()

# %%
a.add_vertex('A')
# Out:
# True

# %%
a.print_graph()
# Out:
# A : []

# %%
b = Graph()
b.add_vertex(1)
b.add_vertex(2)
# Out:
# True

# %%
b.add_edge(1,2)
# Out:
# True

# %%
b.print_graph()
# Out:
# 1 : [2]
# 2 : [1]

# %%
my_g = Graph()
my_g.add_vertex('A')
my_g.add_vertex('B')
my_g.add_vertex('C')
# Out:
# True

# %%
my_g.add_edge('A','B')
my_g.add_edge('B','C')
my_g.add_edge('C','A')
# Out:
# True

# %%
my_g.print_graph()
# Out:
# A : ['B', 'C']
# B : ['A', 'C']
# C : ['B', 'A']

# %%
my_g.remove_edge('A','B')
# Out:
# True

# %%
my_g.print_graph()
# Out:
# A : ['C']
# B : ['C']
# C : ['B', 'A']

# %%
my_g2 = Graph()
my_g2.add_vertex('A')
my_g2.add_vertex('B')
my_g2.add_vertex('C')
my_g2.add_vertex('D')
my_g2.add_edge('A','B')
my_g2.add_edge('B','C')
my_g2.add_edge('C','A')
my_g2.print_graph()
# Out:
# A : ['B', 'C']
# B : ['A', 'C']
# C : ['B', 'A']
# D : []

# %%
my_g2.remove_edge('A','D')
# Out:
# True

# %%
my_g2.print_graph()
# Out:
# A : ['B', 'C']
# B : ['A', 'C']
# C : ['B', 'A']
# D : []

# %%
my_g3 = Graph()
my_g3.add_vertex('A')
my_g3.add_vertex('B')
my_g3.add_vertex('C')
my_g3.add_vertex('D')

my_g3.add_edge('A','B')
my_g3.add_edge('A','C')
my_g3.add_edge('A','D')
my_g3.add_edge('B','D')
my_g3.add_edge('C','D')

my_g3.print_graph()
# Out:
# A : ['B', 'C', 'D']
# B : ['A', 'D']
# C : ['A', 'D']
# D : ['A', 'B', 'C']

# %% [markdown]
# ![graph11.png](attachment:7d6eb00a-4768-4ac9-8eef-61dc9d0db9e6.png)

# %%
my_g3.remove_vertex('D')
# Out:
# True

# %%
my_g3.print_graph()
# Out:
# A : ['B', 'C']
# B : ['A']
# C : ['A']

# %% [markdown]
# ![graph222.png](attachment:ff3138af-05ac-45c7-a386-817a1c06a147.png)
